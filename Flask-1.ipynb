# %% [markdown]
# ## Q1. What is Flask Framework? What are the advantages of Flask Framework?

# %% [markdown]
# Flask is a web development framework that can be used to develop web
# application easily ,it is a pyhton module thats let us develop a web app
# easily

# %% [markdown]
# Advantages of flask:
#
# 1) Its a very lightweight framework
#
# 2) its a vry flexible framework
#
# 3) Its very scalable
#
# 4) Easy to use framework

# %% [markdown]
# ## Q2. Create a simple Flask application to display ‘Hello World!!’. Attach the screenshot of the output in Jupyter Notebook.

# %% [markdown]
# ![Screenshot%202023-03-05%20at%205.10.19%20PM.png](attachment:Screenshot%202023-03-05%20at%205.10.19%20PM.png)

# %% [markdown]
# ## Q3. What is App routing in Flask? Why do we use app routes?

# %% [markdown]
# app routing means mapping the url to a backend function that will
# manage the logic part

# %% [markdown]
# app route is a function that we used to route the url to the intended
# function

# %% [markdown]
# ![Screenshot%202023-03-05%20at%205.26.11%20PM.png](attachment:Screenshot%202023-03-05%20at%205.26.11%20PM.png)

# %% [markdown]
# ## Q4. Create a “/welcome” route to display the welcome message “Welcome to ABC Corporation” and a “/” route to show the following details:Company Name: ABC Corporation Location: India Contact Detail: 999-999-9999

# %% [markdown]
# ![Screenshot%202023-03-05%20at%206.20.15%20PM.png](attachment:Screenshot%202023-03-05%20at%206.20.15%20PM.png)

# %% [markdown]
# ![Screenshot%202023-03-05%20at%205.37.08%20PM.png](attachment:Screenshot%202023-03-05%20at%205.37.08%20PM.png)

# %% [markdown]
# ## Q5. What function is used in Flask for URL Building? Write a Python code to demonstrate the working of the url_for() function.

# %% [markdown]
# The url_for() function is used to build a URL to the specific function dynamically. The first argument is the name of the specified function, and then we can pass any number of keyword argument corresponding to the variable part of the URL

# %% [markdown]
# ![Screenshot%202023-03-05%20at%207.31.31%20PM.png](attachment:Screenshot%202023-03-05%20at%207.31.31%20PM.png)

# %% [markdown]
# ![Screenshot%202023-03-05%20at%207.31.59%20PM.png](attachment:Screenshot%202023-03-05%20at%207.31.59%20PM.png)
